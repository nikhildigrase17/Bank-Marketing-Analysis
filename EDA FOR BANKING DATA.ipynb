# %% [markdown]
# # PERFORMING EXPLORATORY DATA ANALYSIS ON BANKING DATA

# %% [markdown]
# **STEP.01= IMPORTING LIBRARY(PANDAS)**

# %%
# Importing Library

import pandas as pd,os

# %% [markdown]
# **STEP.02 = LOADING DATASET INTO NOTEBOOK**

# %%
#HERE df is dataframe in PANDAS

bank_df = pd.read_excel('C:\\Users\\abc\\Documents\\MARCH 2022 - NEW\\INTERNSHIP @ INEURON\\BANKING PROJECT\\bankfull1.xlsx')

# %% [markdown]
# **STEP.03= CHECKING THE FIRST 5 AND LAST 5 ROWS OF THE DATASET, using head() & tail()**

# %%
#head
bank_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#tail
bank_df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %% [markdown]
# **STEP.04= CHECKING THE DATAYPE & OTHER INFO OF THE DATASET**

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# **STEP.05= CHECKING THE NULL VALUES OF THE DATASET**

# %%
bank_df.isnull().sum() #this will return the count of null from each columns.
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [raw]
# Since in the given dataset it is mentioned that the null values are present as 'unknown' instead of 'nan/NaN/NuLL',
# thus it is not showing the result.

# %% [markdown]
# **STEP.06= LET'S RENAME THE VARIOUS COLUMNS FOR BETTER UNDERSTANDING**

# %%
#using .rename(columns = {'col1':'new_name'},inplace = true)

bank_df.rename(columns ={'age':'Age_Group','job':'Job_Types','housing':'Housing_Loan','loan':'Personal_Loan'}, inplace = True)
bank_df.rename(columns = {'duration':'Last_Call_Dur','campaign':'Current_FollowUps','pdays':'Contact_Day_Diff'}, inplace = True)
bank_df.rename(columns = {'previous':'Previous_FollowUps', 'poutcome':'Previous_Camp_Status', 'y':'Current_Camp_Status'}, 
                           inplace =True)

# %%
bank_df.head()
# Out:
#    Age_Group     Job_Types  marital  education default  balance Housing_Loan  \
# 0         58    management  married   tertiary      no     2143          yes
# 1         44    technician   single  secondary      no       29          yes
# 2         33  entrepreneur  married  secondary      no        2          yes
# 3         47   blue-collar  married    unknown      no     1506          yes
# 4         33       unknown   single    unknown      no        1           no
#
#   Personal_Loan  contact  day month  Last_Call_Dur  Current_FollowUps  \
# 0            no  unknown    5   may            261                  1
# 1            no  unknown    5   may            151                  1
# 2           yes  unknown    5   may             76                  1
# 3            no  unknown    5   may             92                  1
# 4            no  unknown    5   may            198                  1
#
#    Contact_Day_Diff  Previous_FollowUps Previous_Camp_Status  \
# 0                -1                   0              unknown
# 1                -1                   0              unknown
# 2                -1                   0              unknown
# 3                -1                   0              unknown
# 4                -1                   0              unknown
#
#   Current_Camp_Status
# 0                  no
# 1                  no
# 2                  no
# 3                  no
# 4                  no

# %% [markdown]
# **STEP.07= CATERGORIZING THE NUMERIC COLUMNS IN ORDER TO FIND KEY RELATIONSHIPS GOING AHEAD**

# %% [raw]
# Now this is a very lengthy step, since it requires all the operations to be performed column by columns.

# %% [markdown]
# **STEP.07.1= CREATING FUNCTION FOR (AGE GROUP)**
#
# **x(18-30):Young Adults, x(31-45):Min Age Adults, x(46-60): Veterans, x(>60): Senior Citizen**

# %%
#creating a function.

def age_group(x):
    if x >=18 and x<=30:
        return 'Young Adults'
    elif x>30 and x<=45:
        return 'Mid Age Adults'
    elif x>45 and x<=60:
        return 'Veterans'
    else:
        return 'Senior Citizen'

# %%
#applying function to the column

bank_df['Age_Group'] = bank_df['Age_Group'].apply(age_group)

# %%
#checking value counts after categorizing

bank_df['Age_Group'].value_counts()
# Out:
# Mid Age Adults    23733
# Veterans          13260
# Young Adults       7030
# Senior Citizen     1188
# Name: Age_Group, dtype: int64

# %% [markdown]
# **STEP.07.2= CHECKING THE VALUE COUNTS IN (JOB TYPES) & TREATING THE MISSING VALUES WITH MODE**

# %%
bank_df.Job_Types.value_counts() #Or use { bank_df['Job_Types'].value_counts() }
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: Job_Types, dtype: int64

# %% [raw]
# Above we can see there are 288 unknown null values available in the Job category and it may affect the outcome, so we need to treat them with Mode of the column, since the records are categorical in nature.

# %%
#Finding the mode, so that we can replace it with unknown entires.

bank_df.Job_Types.mode() #or write bank_df['Job_Types'].mode()
# Out:
# 0    blue-collar
# dtype: object

# %%
#Replacing null value with mode column by creating the function

def unknown2bluecollar(x):
    if x == 'unknown':
        return 'blue-collar'
    else:
        return x

# %%
#Applying function on Job_Type

bank_df['Job_Types'] = bank_df['Job_Types'].apply(unknown2bluecollar)

# %%
#Checking after replacing the unknowns with mode

bank_df['Job_Types'].value_counts()
# Out:
# blue-collar      10020
# management        9458
# technician        7597
# admin.            5171
# services          4154
# retired           2264
# self-employed     1579
# entrepreneur      1487
# unemployed        1303
# housemaid         1240
# student            938
# Name: Job_Types, dtype: int64

# %%
bank_df['Job_Types'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'retired', 'admin.', 'services', 'self-employed', 'unemployed',
#        'housemaid', 'student'], dtype=object)

# %% [markdown]
# **STEP.07.2.1= Grouping the Job_Types into White Collar Job/ Blue Collar Job/ Entrepreneur**

# %% [raw]
# •Creating function for job group
#                     •considered desk job as white collar job
#                     •considerd field job as blue collar job
#                     •considerd self-employed as Entrepreneur

# %%
def job_group(x):
    if x == 'admin.' or x == 'management' or x == 'services':
        return 'White Collar'
    elif x == 'blue-collar' or x  == 'housemaid' or x == 'technician':
        return 'Blue Collar'
    elif x == 'entrepreneur' or x == 'self-employed':
        return 'Entrepreneur'
    else:
        return x

# %%
#Applying the grouping function

bank_df['Job_Types'] = bank_df['Job_Types'].apply(job_group)

# %%
#checking the result after applying the function.

bank_df.Job_Types.value_counts()
# Out:
# Blue Collar     18857
# White Collar    18783
# Entrepreneur     3066
# retired          2264
# unemployed       1303
# student           938
# Name: Job_Types, dtype: int64

# %% [markdown]
# **STEP.07.3= CHECKING AND TREATING THE MISSING VALUES FROM EDUCATION COLUMN**

# %%
#checking  null values from column

bank_df['education'].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %% [markdown]
# **The above result shows there are 928 unknown entries, to treat them we need to replace them with MODE of the column**

# %%
#finding the mode of education

bank_df.education.mode()
# Out:
# 0    secondary
# dtype: object

# %%
#Replacing null value with mode column by creating the function

def replace_edu(x):
    if x == 'unknown':
        return 'secondary'
    else:
        return x

# %%
#Applying the function to replace the unknown.

bank_df.education = bank_df.education.apply(replace_edu)

# %%
#checking the result after removing the null values.

bank_df['education'].value_counts()
# Out:
# secondary    25059
# tertiary     13301
# primary       6851
# Name: education, dtype: int64

# %% [markdown]
# **STEP.07.4= CHECKING, GROUPING & TREATING THE MISSING VALUES FROM THE BALANCE COLUMN**

# %% [raw]
# Since all the entries in the Balance are nurmeric thus we will first define a function for the grouping and then apply the grouping to the balance column

# %% [markdown]
# •considered value **< 0** as **negative balance**
#
# •considerd value **> 0** and **<= 500** as **low balance**
#
# •considerd value **> 500** and **<= 4000** as **average balance**
#
# •considerd value **> 4000**  as **high  balance**

# %%
#Creating grouping function for balance

def group_bal(y):
    if y <= 0:
        return 'Negative balance'
    elif (y > 0 and y <= 500):
        return 'Low Balance'
    elif (y > 500 and y <= 4000):
        return 'Average Balance'
    else:
        return 'High Balance'

# %%
#Applying the grouping function to the education column.

bank_df.balance=bank_df.balance.apply(group_bal)

# %%
bank_df.balance.value_counts()
# Out:
# Average Balance     17648
# Low Balance         16385
# Negative balance     7280
# High Balance         3898
# Name: balance, dtype: int64

# %% [markdown]
# **STEP.07.5= CONVERTING THE VALUES IN THE Last_Call_Duration COLUMN FROM SECONDS TO MINTUES & ROUNDING TO 0.**

# %%
#dividing the column with 60 to get values in minutes and using .round(0) function.

bank_df.Last_Call_Dur = (bank_df.Last_Call_Dur / 60).round(0)

# %%
#checking the changes in Last_Call_Dur column

bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan    contact  day month  \
# 0      Average Balance          yes            no    unknown    5   may
# 1          Low Balance          yes            no    unknown    5   may
# 2          Low Balance          yes           yes    unknown    5   may
# 3      Average Balance          yes            no    unknown    5   may
# 4          Low Balance           no            no    unknown    5   may
# ...                ...          ...           ...        ...  ...   ...
# 45206  Average Balance           no            no   cellular   17   nov
# 45207  Average Balance           no            no   cellular   17   nov
# 45208     High Balance           no            no   cellular   17   nov
# 45209  Average Balance           no            no  telephone   17   nov
# 45210  Average Balance           no            no   cellular   17   nov
#
#        Last_Call_Dur  Current_FollowUps  Contact_Day_Diff  Previous_FollowUps  \
# 0                4.0                  1                -1                   0
# 1                3.0                  1                -1                   0
# 2                1.0                  1                -1                   0
# 3                2.0                  1                -1                   0
# 4                3.0                  1                -1                   0
# ...              ...                ...               ...                 ...
# 45206           16.0                  3                -1                   0
# 45207            8.0                  2                -1                   0
# 45208           19.0                  5               184                   3
# 45209            8.0                  4                -1                   0
# 45210            6.0                  2               188                  11
#
#       Previous_Camp_Status Current_Camp_Status
# 0                  unknown                  no
# 1                  unknown                  no
# 2                  unknown                  no
# 3                  unknown                  no
# 4                  unknown                  no
# ...                    ...                 ...
# 45206              unknown                 yes
# 45207              unknown                 yes
# 45208              success                 yes
# 45209              unknown                  no
# 45210                other                  no
#
# [45211 rows x 17 columns]

# %% [markdown]
# **STEP.07.5.1= GROUPING THE VALUES IN THE Last_Call_Duration COLUMN**
#
# •considerd duration **>= 0** and **<= 2** as **short call time**
#
# •considerd duration **> 2** and **<= 5** as **medium call time**
#
# •considerd duration  **> 5** as **high call time**

# %%
#Function for grouping the Last_Call_Dur

def group_LCD(z):
    if (z>=0 and z<=2):
        return 'short call time'
    elif (z>2 and z<=5):
        return 'medium call time'
    else:
        return 'high call time'

# %%
#applying the grouping to the column

bank_df.Last_Call_Dur = bank_df.Last_Call_Dur.apply(group_LCD)

# %%
#Checking the update on the column

bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur  Current_FollowUps  Contact_Day_Diff  \
# 0      medium call time                  1                -1
# 1      medium call time                  1                -1
# 2       short call time                  1                -1
# 3       short call time                  1                -1
# 4      medium call time                  1                -1
# ...                 ...                ...               ...
# 45206    high call time                  3                -1
# 45207    high call time                  2                -1
# 45208    high call time                  5               184
# 45209    high call time                  4                -1
# 45210    high call time                  2               188
#
#        Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0                       0              unknown                  no
# 1                       0              unknown                  no
# 2                       0              unknown                  no
# 3                       0              unknown                  no
# 4                       0              unknown                  no
# ...                   ...                  ...                 ...
# 45206                   0              unknown                 yes
# 45207                   0              unknown                 yes
# 45208                   3              success                 yes
# 45209                   0              unknown                  no
# 45210                  11                other                  no
#
# [45211 rows x 16 columns]

# %%
bank_df.Last_Call_Dur.value_counts()
# Out:
# short call time     18610
# medium call time    15862
# high call time      10739
# Name: Last_Call_Dur, dtype: int64

# %% [markdown]
# **STEP.07.6= DROPPING THE CONTACT COLUMN, SINCE IT IS NOT HELPING TO ANALYSE ANYTHING.**

# %%
#use .drop(['col_name'], axis=1, inplace =true)

bank_df.drop(['contact'],axis=1 ,inplace = True)

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur  Current_FollowUps  Contact_Day_Diff  \
# 0      medium call time                  1                -1
# 1      medium call time                  1                -1
# 2       short call time                  1                -1
# 3       short call time                  1                -1
# 4      medium call time                  1                -1
# ...                 ...                ...               ...
# 45206    high call time                  3                -1
# 45207    high call time                  2                -1
# 45208    high call time                  5               184
# 45209    high call time                  4                -1
# 45210    high call time                  2               188
#
#        Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0                       0              unknown                  no
# 1                       0              unknown                  no
# 2                       0              unknown                  no
# 3                       0              unknown                  no
# 4                       0              unknown                  no
# ...                   ...                  ...                 ...
# 45206                   0              unknown                 yes
# 45207                   0              unknown                 yes
# 45208                   3              success                 yes
# 45209                   0              unknown                  no
# 45210                  11                other                  no
#
# [45211 rows x 16 columns]

# %% [markdown]
# **STEP.07.7= GROUPING THE Current_FollowUps Column**
#
# •cosidered value **>0** and **<=5** as **upto 5 followups**
#
# •considered value **>5** as **more than 5 followups**

# %%
#Fuction for grouping the Current_FollowUps

def group_followup(x):
    if (x>0 and x<=5):
        return 'Upto 5 followups'
    else:
        return 'More than 5 followups'

# %%
#Applying the function to the respective column

bank_df.Current_FollowUps = bank_df.Current_FollowUps.apply(group_followup)

# %%
bank_df.Current_FollowUps.value_counts()
# Out:
# Upto 5 followups         40856
# More than 5 followups     4355
# Name: Current_FollowUps, dtype: int64

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur Current_FollowUps  Contact_Day_Diff  \
# 0      medium call time  Upto 5 followups                -1
# 1      medium call time  Upto 5 followups                -1
# 2       short call time  Upto 5 followups                -1
# 3       short call time  Upto 5 followups                -1
# 4      medium call time  Upto 5 followups                -1
# ...                 ...               ...               ...
# 45206    high call time  Upto 5 followups                -1
# 45207    high call time  Upto 5 followups                -1
# 45208    high call time  Upto 5 followups               184
# 45209    high call time  Upto 5 followups                -1
# 45210    high call time  Upto 5 followups               188
#
#        Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0                       0              unknown                  no
# 1                       0              unknown                  no
# 2                       0              unknown                  no
# 3                       0              unknown                  no
# 4                       0              unknown                  no
# ...                   ...                  ...                 ...
# 45206                   0              unknown                 yes
# 45207                   0              unknown                 yes
# 45208                   3              success                 yes
# 45209                   0              unknown                  no
# 45210                  11                other                  no
#
# [45211 rows x 16 columns]

# %% [markdown]
# **STEP.07.8= GROUPING THE Contact_Day_Diff Column**
#
# •consider values **=-1** as **Not Contacted**
#
# •consider values **>=0** and **<=90** as **0-3 Months Back**
#
# •consider values **>90** and **<=180** as **3-6 Months Back**
#
# •consider values **>180** as **More Than 6 Months**

# %%
# creating function for Contact_Day_Diff column group

def group_CDF(x):
    if x == -1:
        return 'Not Contacted'
    elif x >= 0 and x <= 90:
        return '0-3 Months Back'
    elif x > 90 and x <= 180:
        return '3-6 Months Back'
    else:
        return 'More Than 6 Months'

# %%
#Applying the function to the column

bank_df.Contact_Day_Diff = bank_df.Contact_Day_Diff.apply(group_CDF)

# %%
bank_df.Contact_Day_Diff.value_counts()
# Out:
# Not Contacted         36954
# More Than 6 Months     5059
# 3-6 Months Back        2480
# 0-3 Months Back         718
# Name: Contact_Day_Diff, dtype: int64

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur Current_FollowUps    Contact_Day_Diff  \
# 0      medium call time  Upto 5 followups       Not Contacted
# 1      medium call time  Upto 5 followups       Not Contacted
# 2       short call time  Upto 5 followups       Not Contacted
# 3       short call time  Upto 5 followups       Not Contacted
# 4      medium call time  Upto 5 followups       Not Contacted
# ...                 ...               ...                 ...
# 45206    high call time  Upto 5 followups       Not Contacted
# 45207    high call time  Upto 5 followups       Not Contacted
# 45208    high call time  Upto 5 followups  More Than 6 Months
# 45209    high call time  Upto 5 followups       Not Contacted
# 45210    high call time  Upto 5 followups  More Than 6 Months
#
#        Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0                       0              unknown                  no
# 1                       0              unknown                  no
# 2                       0              unknown                  no
# 3                       0              unknown                  no
# 4                       0              unknown                  no
# ...                   ...                  ...                 ...
# 45206                   0              unknown                 yes
# 45207                   0              unknown                 yes
# 45208                   3              success                 yes
# 45209                   0              unknown                  no
# 45210                  11                other                  no
#
# [45211 rows x 16 columns]

# %% [markdown]
# **STEP.07.9= GROUPING THE Previous_FollowUps Column**
#
# •cosidered value **>=0** and **<=5** as **upto 5 followups**
#
# •considered value **>5** as **more than 5 followups**

# %%
#Function for grouping the previous followups column

def previous_followup(x):
    if x >= 0 and x <=5:
        return 'Upto 5 followups'
    else:
        return 'More Than 5 followups'

# %%
bank_df.Previous_FollowUps = bank_df.Previous_FollowUps.apply(previous_followup)

# %%
bank_df.Previous_FollowUps.value_counts()
# Out:
# Upto 5 followups         44147
# More Than 5 followups     1064
# Name: Previous_FollowUps, dtype: int64

# %%
bank_df.Previous_FollowUps.unique()
# Out:
# array(['Upto 5 followups', 'More Than 5 followups'], dtype=object)

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur Current_FollowUps    Contact_Day_Diff  \
# 0      medium call time  Upto 5 followups       Not Contacted
# 1      medium call time  Upto 5 followups       Not Contacted
# 2       short call time  Upto 5 followups       Not Contacted
# 3       short call time  Upto 5 followups       Not Contacted
# 4      medium call time  Upto 5 followups       Not Contacted
# ...                 ...               ...                 ...
# 45206    high call time  Upto 5 followups       Not Contacted
# 45207    high call time  Upto 5 followups       Not Contacted
# 45208    high call time  Upto 5 followups  More Than 6 Months
# 45209    high call time  Upto 5 followups       Not Contacted
# 45210    high call time  Upto 5 followups  More Than 6 Months
#
#           Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0           Upto 5 followups              unknown                  no
# 1           Upto 5 followups              unknown                  no
# 2           Upto 5 followups              unknown                  no
# 3           Upto 5 followups              unknown                  no
# 4           Upto 5 followups              unknown                  no
# ...                      ...                  ...                 ...
# 45206       Upto 5 followups              unknown                 yes
# 45207       Upto 5 followups              unknown                 yes
# 45208       Upto 5 followups              success                 yes
# 45209       Upto 5 followups              unknown                  no
# 45210  More Than 5 followups                other                  no
#
# [45211 rows x 16 columns]

# %% [markdown]
# **STEP.07.10= OPERATING THE Previous_camp_Status COLUMN**
#
# •**We need to the check the view counts and uniqueness of the entries**
#
# •**Replacing null values (i.e 'unknown') with not contacted and (others) with failure**

# %%
bank_df.Previous_Camp_Status.unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
bank_df.Previous_Camp_Status.value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: Previous_Camp_Status, dtype: int64

# %% [raw]
# The above result shows we have 36k 'unknown' records, we will consider them as Not Contacted
#
# & 1.8k 'other' does not defines anything, thus we will consider it as a failure.

# %%
#replacing the unwanted records: unknown=Not Contacted, other=failure

bank_df.Previous_Camp_Status = bank_df.Previous_Camp_Status.replace('unknown','not contacted').replace('other','failure')

# %%
#Checking the changes after replacement

bank_df.Previous_Camp_Status.value_counts()
# Out:
# not contacted    36959
# failure           6741
# success           1511
# Name: Previous_Camp_Status, dtype: int64

# %%
#Suppose replacing the categories once again to assign meaningfull name

bank_df.Previous_Camp_Status=bank_df.Previous_Camp_Status.replace('success','P Subscribed').replace('failure','P N Subscribed')

# %%
#Checking the changes after replacement 2.o


bank_df.Previous_Camp_Status.value_counts()
# Out:
# not contacted     36959
# P N Subscribed     6741
# P Subscribed       1511
# Name: Previous_Camp_Status, dtype: int64

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur Current_FollowUps    Contact_Day_Diff  \
# 0      medium call time  Upto 5 followups       Not Contacted
# 1      medium call time  Upto 5 followups       Not Contacted
# 2       short call time  Upto 5 followups       Not Contacted
# 3       short call time  Upto 5 followups       Not Contacted
# 4      medium call time  Upto 5 followups       Not Contacted
# ...                 ...               ...                 ...
# 45206    high call time  Upto 5 followups       Not Contacted
# 45207    high call time  Upto 5 followups       Not Contacted
# 45208    high call time  Upto 5 followups  More Than 6 Months
# 45209    high call time  Upto 5 followups       Not Contacted
# 45210    high call time  Upto 5 followups  More Than 6 Months
#
#           Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0           Upto 5 followups        not contacted                  no
# 1           Upto 5 followups        not contacted                  no
# 2           Upto 5 followups        not contacted                  no
# 3           Upto 5 followups        not contacted                  no
# 4           Upto 5 followups        not contacted                  no
# ...                      ...                  ...                 ...
# 45206       Upto 5 followups        not contacted                 yes
# 45207       Upto 5 followups        not contacted                 yes
# 45208       Upto 5 followups         P Subscribed                 yes
# 45209       Upto 5 followups        not contacted                  no
# 45210  More Than 5 followups       P N Subscribed                  no
#
# [45211 rows x 16 columns]

# %% [markdown]
# **STEP.07.11= OPERATING THE Current_Camp_Status COLUMN**
#
# •**Replacing yes** = **Subscribed** & **no** = **Not Subscribed**

# %%
bank_df.Current_Camp_Status = bank_df.Current_Camp_Status.replace('yes','Subscribed').replace('no','Not Subscribed ')

# %%
bank_df.Current_Camp_Status.value_counts()
# Out:
# Not Subscribed     39922
# Subscribed          5289
# Name: Current_Camp_Status, dtype: int64

# %%
bank_df
# Out:
#             Age_Group     Job_Types   marital  education default  \
# 0            Veterans  White Collar   married   tertiary      no
# 1      Mid Age Adults   Blue Collar    single  secondary      no
# 2      Mid Age Adults  Entrepreneur   married  secondary      no
# 3            Veterans   Blue Collar   married  secondary      no
# 4      Mid Age Adults   Blue Collar    single  secondary      no
# ...               ...           ...       ...        ...     ...
# 45206        Veterans   Blue Collar   married   tertiary      no
# 45207  Senior Citizen       retired  divorced    primary      no
# 45208  Senior Citizen       retired   married  secondary      no
# 45209        Veterans   Blue Collar   married  secondary      no
# 45210  Mid Age Adults  Entrepreneur   married  secondary      no
#
#                balance Housing_Loan Personal_Loan  day month  \
# 0      Average Balance          yes            no    5   may
# 1          Low Balance          yes            no    5   may
# 2          Low Balance          yes           yes    5   may
# 3      Average Balance          yes            no    5   may
# 4          Low Balance           no            no    5   may
# ...                ...          ...           ...  ...   ...
# 45206  Average Balance           no            no   17   nov
# 45207  Average Balance           no            no   17   nov
# 45208     High Balance           no            no   17   nov
# 45209  Average Balance           no            no   17   nov
# 45210  Average Balance           no            no   17   nov
#
#           Last_Call_Dur Current_FollowUps    Contact_Day_Diff  \
# 0      medium call time  Upto 5 followups       Not Contacted
# 1      medium call time  Upto 5 followups       Not Contacted
# 2       short call time  Upto 5 followups       Not Contacted
# 3       short call time  Upto 5 followups       Not Contacted
# 4      medium call time  Upto 5 followups       Not Contacted
# ...                 ...               ...                 ...
# 45206    high call time  Upto 5 followups       Not Contacted
# 45207    high call time  Upto 5 followups       Not Contacted
# 45208    high call time  Upto 5 followups  More Than 6 Months
# 45209    high call time  Upto 5 followups       Not Contacted
# 45210    high call time  Upto 5 followups  More Than 6 Months
#
#           Previous_FollowUps Previous_Camp_Status Current_Camp_Status
# 0           Upto 5 followups        not contacted     Not Subscribed
# 1           Upto 5 followups        not contacted     Not Subscribed
# 2           Upto 5 followups        not contacted     Not Subscribed
# 3           Upto 5 followups        not contacted     Not Subscribed
# 4           Upto 5 followups        not contacted     Not Subscribed
# ...                      ...                  ...                 ...
# 45206       Upto 5 followups        not contacted          Subscribed
# 45207       Upto 5 followups        not contacted          Subscribed
# 45208       Upto 5 followups         P Subscribed          Subscribed
# 45209       Upto 5 followups        not contacted     Not Subscribed
# 45210  More Than 5 followups       P N Subscribed     Not Subscribed
#
# [45211 rows x 16 columns]

# %% [raw]
# TILL HERE, WE HAVE PERFORMED THE EXPLORATORY DATA ANALYSIS AND WE HAVE GOT THE FINAL CLEANED TABLE WHICH HAS BEEN CATEGORIZED.

# %% [markdown]
# **STEP.08 = SAVE THE FILE**
#
# **Now it's time to save the file, so that we can perform data visualization after hooking up to POWER BI**

# %%
bank_df.to_csv('Final_Banking_file.csv')
